# %% [markdown]
# ## Multifunctional Fine Tuned Retrieval-Based Chatbot Leveraging RoBERTa , BART Transformers

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# ##### As internet digital communication has expanded rapidly, there's been a rising need for smarter and more responsive chatbots to enhance human-computer interactions which is very much helpful with customer interaction and etc. Traditional rule-based chatbots often fail to understand the complexity and nuances of human language. As there is a need for a versatile and adaptive chatbot that can comprehend and generate contextually relevant responses, leveraging state-of-the-art natural language processing (NLP) techniques.

# %% [markdown]
# ### Objective

# %% [markdown]
# ##### The object of the project is to create two chatbots
#
# ##### First would be a fine tuned and retrieval-based chatbot
#
# ##### Second would be a Fined-Tuned chatbot
#
# ##### A sophisticated fine tuned and  retrieval-based chatbot would integrate RoBERTa , Sentence Transformer and advanced NLP methodologies. While the Fine Tuned chatbot will be fine tuned using Bart transformer. These chatbot's aims to enhance the quality and relevance of user interactions by employing sentence transformers for semantic understanding, cosine similarity for response retrieval, and BART for conditional text generation. It also checks the intent of the questions are whether positive or negative in nature using text blob which helps to give better experience to the user.
#
# ##### The chabot will be able to answer questions related to healthcare  and also be able to keep up with general conversations.

# %% [markdown]
# ### Dataset

# %% [markdown]
# ##### The dataset consist of questions and answers pairs. Which will be used for training and retrieval purposes. This dataset have entries of plant disease cure  and conversational questions and answers.

# %% [markdown]
# ##### Import Libraries

# %%
import torch
import re
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer , InputExample, losses

# %%
import pandas as pd

# 1. Load your dataset (use pd.read_excel for .xlsx files)
df = pd.read_excel("/content/Plant_Disease_chatbot_data.xlsx")

# 2. Rename columns to match the code's expectation
df = df.rename(columns={"Question": "query", "Answer": "response"})

# 3. Add dummy columns (required by the notebook's 'drop' and 'value_counts' functions)
df["domain"] = "plant_disease"
df["intent"] = "faq"

# 4. Save the file with the name your notebook expects
df.to_csv("chatbot_data.csv", index=False)

# Check the result
print(df.head())
# Out:
#                                                query  \
# 0  What is the first step in curing a spider mite...
# 1  How does high-pressure water spray help cure s...
# 2                Why is pruning useful in mite cure?
# 3  Can dust reduction be considered a cure for sp...
# 4  How does improving air circulation cure mite o...
#
#                                             response         domain intent
# 0  Immediately remove and destroy heavily infeste...  plant_disease    faq
# 1  It physically dislodges mites from leaves; rep...  plant_disease    faq
# 2  It eliminates infestation hotspots and improve...  plant_disease    faq
# 3  Yes, reducing dust lowers stress on plants and...  plant_disease    faq
# 4  Better airflow reduces hot, dry microclimates ...  plant_disease    faq

# %% [markdown]
# ##### Reading CSV File

# %%
chatDF = pd.read_csv("chatbot_data.csv")

# %%
chatDF.head()
# Out:
#                                                query  \
# 0  What is the first step in curing a spider mite...
# 1  How does high-pressure water spray help cure s...
# 2                Why is pruning useful in mite cure?
# 3  Can dust reduction be considered a cure for sp...
# 4  How does improving air circulation cure mite o...
#
#                                             response         domain intent
# 0  Immediately remove and destroy heavily infeste...  plant_disease    faq
# 1  It physically dislodges mites from leaves; rep...  plant_disease    faq
# 2  It eliminates infestation hotspots and improve...  plant_disease    faq
# 3  Yes, reducing dust lowers stress on plants and...  plant_disease    faq
# 4  Better airflow reduces hot, dry microclimates ...  plant_disease    faq

# %% [markdown]
# The head returns the whole DataFrame which consist of four columns "query" , "response" , "intent" and "domain".

# %% [markdown]
# .

# %% [markdown]
# ##### Using "value_counts()" to count the occurences of unique values.

# %%
chatDF["domain"].value_counts()
# Out:
# domain
# plant_disease    6189
# Name: count, dtype: int64

# %% [markdown]
# The dataset consist of Three major domains healthcare , finance and conversation. Healthcare has the highest count, followed by finance, and then conversation.

# %% [markdown]
# .

# %% [markdown]
# ##### Checking the shape of the dataset

# %%
chatDF.shape
# Out:
# (6189, 4)

# %% [markdown]
# Dataset has 1676 rows and 4 columns.

# %% [markdown]
# .

# %% [markdown]
# ##### Cleaning the text data

# %%
def clean_text(text):
    if not isinstance(text, str):
        text = str(text)
    text = re.sub(r'\r\n', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'[?.,@!#$%^&*()]','',text)
    text = re.sub(r'\d+','',text)
    text = text.strip().lower()
    return text

# %% [markdown]
# .

# %% [markdown]
# ##### Extracting Response and Query Columns from chatDF DataFrame

# %%
responseDF = chatDF["response"]

# %% [markdown]
# ##### Apply cleaning to response and query columns

# %%
responseDF = responseDF.apply(clean_text)

# %%
responseDF[0]
# Out:
# 'immediately remove and destroy heavily infested leaves to slow population spread'

# %%
len(responseDF)
# Out:
# 6189

# %% [markdown]
# .

# %% [markdown]
# ##### Cleaning and Storing chatDF into newChatDF DataFrame

# %%
newChatDF = chatDF.applymap(clean_text)
# Out:
# /tmp/ipython-input-853497857.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   newChatDF = chatDF.applymap(clean_text)

# %%
newChatDF.head()
# Out:
#                                                query  \
# 0  what is the first step in curing a spider mite...
# 1  how does high-pressure water spray help cure s...
# 2                 why is pruning useful in mite cure
# 3  can dust reduction be considered a cure for sp...
# 4  how does improving air circulation cure mite o...
#
#                                             response         domain intent
# 0  immediately remove and destroy heavily infeste...  plant_disease    faq
# 1  it physically dislodges mites from leaves; rep...  plant_disease    faq
# 2  it eliminates infestation hotspots and improve...  plant_disease    faq
# 3  yes reducing dust lowers stress on plants and ...  plant_disease    faq
# 4  better airflow reduces hot dry microclimates w...  plant_disease    faq

# %%
# !pip install nlpaug
# Out:
# Collecting nlpaug
#   Downloading nlpaug-1.1.11-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.12/dist-packages (from nlpaug) (2.0.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from nlpaug) (2.2.2)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from nlpaug) (2.32.4)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from nlpaug) (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown>=4.0.0->nlpaug) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown>=4.0.0->nlpaug) (3.20.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown>=4.0.0->nlpaug) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->nlpaug) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->nlpaug) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2.0->nlpaug) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22.0->nlpaug) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22.0->nlpaug) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22.0->nlpaug) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22.0->nlpaug) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->nlpaug) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug) (4.15.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.0.0->nlpaug) (1.7.1)
# Downloading nlpaug-1.1.11-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 13.2 MB/s eta 0:00:00
# Installing collected packages: nlpaug
# Successfully installed nlpaug-1.1.11

# %% [markdown]
# ##### Contextual Word Embeddings Augmentation with NLPaug
#
# Importing nlpaug library

# %%
import nlpaug.augmenter.word as naw

# %% [markdown]
# ##### Initialize the augmenter

# %%
aug = naw.ContextualWordEmbsAug(model_path='bert-base-uncased', action="insert")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# The following layers were not sharded: bert.encoder.layer.*.attention.self.value.weight, bert.encoder.layer.*.attention.output.LayerNorm.weight, bert.encoder.layer.*.attention.self.key.bias, bert.embeddings.position_embeddings.weight, bert.embeddings.LayerNorm.weight, bert.encoder.layer.*.output.dense.bias, bert.encoder.layer.*.attention.output.dense.bias, bert.encoder.layer.*.intermediate.dense.bias, cls.predictions.decoder.weight, cls.predictions.decoder.bias, bert.encoder.layer.*.attention.self.query.weight, bert.encoder.layer.*.attention.self.query.bias, bert.encoder.layer.*.intermediate.dense.weight, cls.predictions.transform.LayerNorm.bias, bert.encoder.layer.*.output.LayerNorm.bias, bert.embeddings.token_type_embeddings.weight, cls.predictions.transform.dense.weight, cls.predictions.transform.LayerNorm.weight, bert.encoder.layer.*.attention.self.value.bias, bert.encoder.layer.*.attention.self.key.weight, bert.encoder.layer.*.attention.output.dense.weight, bert.encoder.layer.*.output.LayerNorm.weight, bert.embeddings.word_embeddings.weight, cls.predictions.transform.dense.bias, bert.embeddings.LayerNorm.bias, bert.encoder.layer.*.attention.output.LayerNorm.bias, bert.encoder.layer.*.output.dense.weight, cls.predictions.bias

# %% [markdown]
# ##### Function to augment a single sentence

# %%
def augment_text(text):
    return aug.augment(text)

# %% [markdown]
# ##### Applying Text Augmentation to DataFrame

# %%
newChatDF["augmentedQuery"] = newChatDF["query"].apply(augment_text)

# %%
# Save to CSV
newChatDF.to_csv("augmented_queries.csv", index=False)

# %%
#if you have save the augmented file and now you want to use it

import pandas as pd
import ast

# Load the file you already saved
df = pd.read_csv("/content/augmented_queries-2.csv")

# Function to fix the list format
def clean_aug_text(text):
    if isinstance(text, str) and text.strip().startswith("["):
        try:
            actual_list = ast.literal_eval(text)
            return " ".join(actual_list)
        except:
            return text
    return str(text)

# Apply the fix
if 'augmentedQuery' in df.columns:
    df['augmentedQuery'] = df['augmentedQuery'].apply(clean_aug_text).fillna("")
    df['full_input'] = df['query'].astype(str) + " " + df['augmentedQuery']
else:
    df['full_input'] = df['query'].astype(str)

print("✅ Data loaded and fixed.")
# Out:
# ✅ Data loaded and fixed.

# %%
print(newChatDF.columns)
# Out:
# Index(['query', 'response', 'domain', 'intent'], dtype='object')

# %% [markdown]
# ##### Converting the list rows into string

# %%
import pandas as pd
import ast
import os

# 1. Load the file
file_path = "/content/augmented_queries.csv"

if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print("✅ File loaded successfully.")

    # 2. Fix: Handle missing 'augmentedQuery' column safely
    if 'augmentedQuery' not in df.columns:
        print("⚠️ Warning: 'augmentedQuery' column not found in CSV.")
        print("   -> Using 'query' column as input instead.")
        df['full_input'] = df['query'].astype(str).fillna("")
        # Add an empty 'augmentedQuery' column for consistency if it's missing from the CSV
        df['augmentedQuery'] = ''
    else:
        # If it exists, process it as before
        print("ℹ️ 'augmentedQuery' found. combining with 'query'.")

        def clean_aug_text(text):
            if isinstance(text, str) and text.strip().startswith("["):
                try:
                    actual_list = ast.literal_eval(text)
                    return " ".join(actual_list)
                except:
                    return text
            return str(text)

        df['augmentedQuery'] = df['augmentedQuery'].apply(clean_aug_text).fillna("")
        df['full_input'] = df['query'].astype(str) + " " + df['augmentedQuery']

    # 3. Ensure response column is clean
    df['response'] = df['response'].astype(str).fillna("")

    # IMPORTANT: Update newChatDF with the processed DataFrame
    global newChatDF
    newChatDF = df.copy()

    print(f"✅ Data Ready for Training. Rows: {len(newChatDF)}")
    print(f"   Sample Input: {newChatDF['full_input'].iloc[0]}")

else:
    print(f"❌ Error: File not found at {file_path}. Please make sure you uploaded it.")
# Out:
# ✅ File loaded successfully.
# ⚠️ Warning: 'augmentedQuery' column not found in CSV.
#    -> Using 'query' column as input instead.
# ✅ Data Ready for Training. Rows: 6189
#    Sample Input: what is the first step in curing a spider mite outbreak on tomato what is the first completed step in disease curing... a spider mite whether outbreak or on tomato

# %%
# Rename 'full_input' to 'fullQuery' to match the rest of the notebook
newChatDF = newChatDF.rename(columns={"full_input": "fullQuery"})

# Verify it is correct
print(newChatDF.columns)
# Out:
# Index(['query', 'response', 'domain', 'intent'], dtype='object')

# %%
# 1. Copy the fixed data from 'df' to 'newChatDF'
newChatDF = df.copy()

# 2. Rename the column to match what the training code expects
newChatDF = newChatDF.rename(columns={"full_input": "fullQuery"})

# 3. Add back helper columns (to prevent errors later)
newChatDF["domain"] = "plant_disease"
newChatDF["intent"] = "faq"

# 4. Verify that 'fullQuery' is now present
print("Columns:", newChatDF.columns)
print("-" * 30)
print(newChatDF[["fullQuery", "response"]].head(1))
# Out:
# Columns: Index(['query', 'response', 'fullQuery', 'domain', 'intent'], dtype='object')
# ------------------------------
#                                            fullQuery  \
# 0  what is the first step in curing a spider mite...
#
#                                             response
# 0  immediately remove and destroy heavily infeste...

# %% [markdown]
# ##### Checking the columns in newChatDF

# %%
newChatDF.columns
# Out:
# Index(['query', 'response', 'fullQuery', 'domain', 'intent'], dtype='object')

# %% [markdown]
# ##### Dropping the unnecessary columns

# %%
newChatDF = newChatDF.drop(columns=['intent','domain','query','augmentedQuery'])

# %% [markdown]
# ##### Checking the type of "newChatDF"

# %%
type(newChatDF)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### InputExample
#
# ##### "InputExample" is a specific instance of input data, typically consisting of sentences or text pairs, used to demonstrate and evaluate the transformer's ability to generate meaningful sentence embeddings.

# %% [markdown]
# ##### Converting the "newChatDF" DataFrame to InputExample objects with a default label

# %%
default_label = 1.0
input_examples = newChatDF.apply(lambda row: InputExample(
    guid=str(row.name),
    texts=[row['fullQuery'], row['response']],
    label=default_label
), axis=1).tolist()

# %% [markdown]
# In the above code :
#
# **guid** : it gives a unique value to each question and answer pair, helping to keep track of each example distinctly.
#
# **texts** : it combines the "fullQuery" and "response" into a list of two separate text elements.
#
# **label** : it assigns the number 1.0 to each row, indicating a default label, which can be used to signify something like a positive example.
#
# Finally, the apply method processes each row, creating InputExample objects, and .tolist() converts the entire result into a list of these objects.

# %% [markdown]
# .

# %% [markdown]
# ##### Printing Input Examples

# %%
for example in input_examples:
    print(example)
# Out:
# <InputExample> label: 1.0, texts: what is the first step in curing a spider mite outbreak on tomato what is the first completed step in disease curing... a spider mite whether outbreak or on tomato; immediately remove and destroy heavily infested leaves to slow population spread
# <InputExample> label: 1.0, texts: how does high-pressure water spray help cure spider mites how precisely does high - pressure water spray help establish cure in spider flu mites; it physically dislodges mites from leaves; repeat every – days for best results
# <InputExample> label: 1.0, texts: why is pruning useful in mite cure why what is root pruning useful in mite disease cure; it eliminates infestation hotspots and improves spray penetration
# <InputExample> label: 1.0, texts: can dust reduction be considered a cure for spider mites mice can induced dust reduction be also considered a cure for various spider mites; yes reducing dust lowers stress on plants and directly reduces mite survival
# <InputExample> label: 1.0, texts: how does improving air circulation cure mite outbreaks how well does continually improving air circulation cure mite virus outbreaks; better airflow reduces hot dry microclimates where mites thrive
# <InputExample> label: 1.0, texts: can overhead irrigation cure spider mites can overhead air irrigation prevent cure on spider mites; yes wetting foliage reduces mite activity and reproduction
# <InputExample> label: 1.0, texts: is mulching a cure is essential mulching as a cure; indirectly—it reduces dust and stress making plants less favorable for mites
# <InputExample> label: 1.0, texts: how does regular scouting help cure infestations also how does regular bush scouting activity help cure infestations; early detection allows timely interventions before populations explode
# <InputExample> label: 1.0, texts: can crop sanitation cure mites can crop and sanitation cure insect mites; yes removing weeds and volunteer plants removes alternate hosts for mites
# <InputExample> label: 1.0, texts: why is shade netting sometimes used in greenhouses for mite cure ... why that is shade netting even sometimes used in indoor greenhouses for mite cure; it reduces temperature stress slowing mite reproduction
# <InputExample> label: 1.0, texts: what predator is most effective for curing mites in greenhouses and what constitutes predator control is most effective for curing mites live in greenhouses; phytoseiulus persimilis a specialist predatory mite
# <InputExample> label: 1.0, texts: how does neoseiulus californicus cure infestations unclear how efficiently does the neoseiulus californicus even cure infestations; it tolerates harsher environments and feeds on spider mites even at low densities
# <InputExample> label: 1.0, texts: can predatory insects cure mites its can survive predatory insects cure mites; yes lady beetles stethorus punctillum and lacewings feed on mites
# <InputExample> label: 1.0, texts: how does amblyseius andersoni contribute to cure just how exactly does amblyseius andersoni contribute more to the cure; it provides broad-spectrum predation suppressing mites in diverse conditions
# <InputExample> label: 1.0, texts: can biological cures work in the field [UNK] can biological cures work in across the whole field; yes but they are most successful in greenhouses and protected crops
# <InputExample> label: 1.0, texts: how do entomopathogenic fungi cure mite infestations or how now do some entomopathogenic fungi cure wildlife mite flu infestations; fungi like beauveria bassiana infect and kill mites directly
# <InputExample> label: 1.0, texts: can fungal biopesticides cure mites in high populations but can fungal biopesticides cure these mites isolated in high growth populations; yes but they are more effective when applied preventively or at low densities
# <InputExample> label: 1.0, texts: what is the advantage of using biocontrol agents in cure what is the advantage now of out using the biocontrol agents like in cure; they provide long-term suppression without chemical resistance risk
# <InputExample> label: 1.0, texts: do predators survive after mites are cured can do other predators survive after mites are partly cured; some decline without prey; others feed on pollen and survive for future outbreaks
# <InputExample> label: 1.0, texts: why is predator release timing important in cure why why is predator energy release timing important more in cure; early release ensures predators establish before mite numbers explode
# <InputExample> label: 1.0, texts: how does insecticidal soap cure mites even how else does insecticidal soap easily cure mites; it breaks down mite cell membranes on contact killing them
# <InputExample> label: 1.0, texts: how does neem oil cure spider mites how fast does neem oil actually cure red spider mites; it acts as an insect growth regulator and smothering agent
# <InputExample> label: 1.0, texts: can horticultural oils cure mite outbreaks water can horticultural seed oils cure industrial mite outbreaks; yes they suffocate eggs nymphs and adults if sprayed thoroughly
# <InputExample> label: 1.0, texts: why must oils/soaps be applied to the underside of leaves why must essential oils / soaps can be applied to the bare underside bark of leaves; that’s where most mites and eggs are located
# <InputExample> label: 1.0, texts: how many applications of oil/soap sprays are needed for a cure how many more applications out of the oil / other soap sprays we are needed for a cure; usually – applications at – day intervals
# <InputExample> label: 1.0, texts: can plant extracts cure mites extracts can be plant extracts cure mites; yes extracts like garlic and chili reduce populations but act more slowly
# <InputExample> label: 1.0, texts: what precaution must be taken when curing with oils in hot weather what a precaution must not be then taken when curing with edible oils in hot dry weather; avoid spraying during high temperatures to prevent leaf burn
# <InputExample> label: 1.0, texts: do organic cures provide complete eradication what do clean organic cures provide nearly complete eradication; they control mites effectively but rarely eradicate them entirely
# <InputExample> label: 1.0, texts: can organic cures be mixed with biological cures can organic cures safely be mixed with animal biological synthetic cures; yes if the products are selective and safe for beneficials
# <InputExample> label: 1.0, texts: why are organic cures favored in greenhouse tomatoes what why are organic plant cures this favored in greenhouse tomatoes; they are safer for workers predators and continuous production cycles
# <InputExample> label: 1.0, texts: what role do miticides play in curing spider mites of what role do insect miticides play it in curing spider larvae mites; they provide rapid suppression when infestations exceed thresholds
# <InputExample> label: 1.0, texts: how does abamectin cure mites in how long does an abamectin cure mites; it disrupts nerve transmission killing mites after ingestion/contact
# <InputExample> label: 1.0, texts: how does spiromesifen work in cure how does some spiromesifen work if in a cure; it inhibits lipid biosynthesis targeting immature stages
# <InputExample> label: 1.0, texts: why is bifenazate used for mite cure and why else is bifenazate ever used again for mite cure; it provides fast knockdown and residual activity
# <InputExample> label: 1.0, texts: what stage does hexythiazox cure what this stage does form hexythiazox plus cure; it targets eggs and immature stages but not adults
# <InputExample> label: 1.0, texts: how does fenpyroximate cure mite infestations then how does using fenpyroximate cure paralysis mite fungal infestations; it disrupts energy production in mites leading to death
# <InputExample> label: 1.0, texts: why is thorough spray coverage critical in chemical cure so why is thorough spray or coverage critical in chemical toilet cure; spider mites hide on leaf undersides making contact coverage essential
# <InputExample> label: 1.0, texts: can repeated use of one miticide cure mites effectively can use repeated needle use out of even one miticide cure mites effectively; no it leads to resistance — rotation is essential
# <InputExample> label: 1.0, texts: what happens if pyrethroids are used for cure what happens if my pyrethroids here are never used for this cure; they may worsen infestations by killing predators and sparing mites
# <InputExample> label: 1.0, texts: how can chemical cure be combined with biological control how can chemical cure be combined simply with a biological response control; by choosing selective miticides that are safe for predatory mites
# <InputExample> label: 1.0, texts: what is the best cure strategy overall or what is ultimately the best health cure strategy overall; integrated pest management ipm: combine cultural biological and chemical cures
# <InputExample> label: 1.0, texts: how does early intervention improve cure success how much does any early intervention improve cure or success; smaller populations are easier to control with non-chemical measures
# <InputExample> label: 1.0, texts: why is crop rotation not a cure for mites but why is crop rotation now not a sure cure for mites; mites are mobile and polyphagous; they survive on many host plants
# <InputExample> label: 1.0, texts: how does irrigation management contribute to cure how does municipal irrigation management system contribute economically to cure; prevents drought stress reducing plant susceptibility and mite reproduction
# <InputExample> label: 1.0, texts: how does record-keeping help future cures how much does record - keeping system help for future cures; it tracks which methods worked preventing repeated failures
# <InputExample> label: 1.0, texts: why must cure strategies change with environment when why must they cure strategies change interaction with environment; field and greenhouse conditions favor different cure approaches
# <InputExample> label: 1.0, texts: how do buffer zone sprays help cure and how will do buffer separation zone sprays help cure; treating field edges prevents inward spread of mites
# <InputExample> label: 1.0, texts: can combining water sprays and predators cure outbreaks he can combining water sprays and deter predators together cure outbreaks; yes reducing mite density first makes predators more effective
# <InputExample> label: 1.0, texts: why must phi and rei be respected in chemical cure why not must phi and rei be well respected in some chemical cure; to ensure food safety and worker protection
# <InputExample> label: 1.0, texts: what is the ultimate cure principle for spider mites what is now the one ultimate cancer cure principle for spider mites; prevent explosive populations with early integrated actions rather than relying solely on late-stage chemicals
# <InputExample> label: 1.0, texts: why are precautions more important than cures for spider mites also why are precautions more politically important than cures exist for giant spider mites; because mites multiply rapidly; prevention reduces outbreaks before they become uncontrollable
# <InputExample> label: 1.0, texts: how often should tomato crops be scouted as a precaution how ever often... should tomato crops be immediately scouted as only a precaution; at least weekly and every – days during hot dry weather
# <InputExample> label: 1.0, texts: why should the undersides of leaves be checked during scouting or why exactly should the undersides colour of leaves be checked during bird scouting; spider mites prefer leaf undersides where they hide and lay eggs
# <InputExample> label: 1.0, texts: what is the precautionary value of the white paper shake test what is the final precautionary side value of allowing the little white paper to shake test; it detects mites early by dislodging them onto a contrasting surface
# <InputExample> label: 1.0, texts: why should neighboring crops be monitored too why should neighboring citrus crops really be monitored here too; mites migrate easily between plants greenhouses and fields
# <InputExample> label: 1.0, texts: how do weeds serve as a risk factor and how well do weeds serve as a risk assessment factor; weeds host mites allowing them to survive between crops
# <InputExample> label: 1.0, texts: why is cleaning greenhouse structures important explain why it is cleaning greenhouse structures important; spider mites can overwinter in cracks and plant debris
# <InputExample> label: 1.0, texts: should infested crop residues be composted • should an infested crop soil residues be composted; no residues should be destroyed to prevent mite carryover
# <InputExample> label: 1.0, texts: how do sanitized tools help in precaution then how do non sanitized tools sufficiently help in this precaution; mites can be transferred on pruning shears stakes or equipment
# <InputExample> label: 1.0, texts: why avoid bringing in infested transplants why avoid bringing them in the infested organ transplants; transplants often carry undetected mite eggs or nymphs
# <InputExample> label: 1.0, texts: how does crop rotation help precaution how many does crop rotation actually help as precaution; while not eliminating mites it disrupts continuous tomato monoculture
# <InputExample> label: 1.0, texts: why is dust control considered a precaution to why is dust cloud control considered a crucial precaution; dusty plants are more prone to mite colonization
# <InputExample> label: 1.0, texts: how does maintaining optimal irrigation serve as a precaution about how does also maintaining such optimal wind irrigation serve as a precaution; well-watered plants are less stressed and less susceptible to mite outbreaks
# <InputExample> label: 1.0, texts: why avoid over-fertilization with nitrogen why avoid doing over - fertilization hybrids with high nitrogen; excess nitrogen produces lush foliage that attracts mites
# <InputExample> label: 1.0, texts: how does mulching help in precaution in how does with mulching water help in precaution; it suppresses dust and maintains soil moisture indirectly lowering mite pressure
# <InputExample> label: 1.0, texts: why must greenhouse entry be restricted during outbreaks why must greenhouse air entry standards be routinely restricted during outbreaks; workers can spread mites between plants
# <InputExample> label: 1.0, texts: how does maintaining higher humidity in greenhouses help how far does maintaining higher humidity possible in greenhouses not help; mites prefer dry air; humidity slows their reproduction
# <InputExample> label: 1.0, texts: why should greenhouse vents be screened just why should a greenhouse vents be screened; to prevent entry of windborne mites or alternate hosts
# <InputExample> label: 1.0, texts: how do sticky traps serve as precautionary tools how do such sticky traps actually serve well as additional precautionary tools; they help detect mite movement and monitor populations early
# <InputExample> label: 1.0, texts: why is spacing between tomato plants important in greenhouses unclear why it is genetic spacing between several tomato plants important in greenhouses; proper spacing improves airflow and reduces hot dry zones
# <InputExample> label: 1.0, texts: why release predatory mites preventively or why release predatory fly mites unless preventively; early release establishes predators before pests reach damaging levels
# <InputExample> label: 1.0, texts: can predator survival be ensured without pests only can predator survival thus be ensured without the pests; yes some predatory mites survive on pollen and prevent flare-ups
# <InputExample> label: 1.0, texts: why avoid non-selective insecticides as a precaution for why avoid eating non - selective resistant insecticides as a health precaution; they kill beneficial predators removing natural mite control
# <InputExample> label: 1.0, texts: what’s the role of banker plants as a precaution what ’ ′ s the basic role of banker plants as performing a rescue precaution; they maintain alternative prey/pollen to sustain predators year-round
# <InputExample> label: 1.0, texts: why maintain predator–prey ratio records why actively maintain predator – prey species ratio or records; ensures preventive biocontrol populations remain effective
# <InputExample> label: 1.0, texts: why rotate acaricide modes of action as a precaution why they rotate between acaricide other modes denial of action as a precaution; to prevent resistance buildup in spider mite populations
# <InputExample> label: 1.0, texts: why should phi and rei always be checked why should phi for and then rei just always be checked; to protect workers and ensure safe produce
# <InputExample> label: 1.0, texts: why avoid prophylactic unnecessary sprays why not avoid prophylactic medicine unnecessary pepper sprays; they waste resources and may cause resistance and mite flare-ups
# <InputExample> label: 1.0, texts: what is the precaution regarding spray coverage what then is the precaution item regarding spray site coverage; ensure full coverage of undersides of leaves to avoid survival pockets
# <InputExample> label: 1.0, texts: why avoid mixing incompatible chemicals thus why avoid mixing together incompatible chemicals; it can reduce efficacy or cause plant injury
# <InputExample> label: 1.0, texts: why train workers in mite identification why train workers work in it mite social identification; so infestations are spotted early during routine activities
# <InputExample> label: 1.0, texts: why should workers avoid handling plants after visiting infested fields why should farm workers also avoid infected handling plants after visiting in infested fields; mites hitchhike on clothing and spread quickly
# <InputExample> label: 1.0, texts: why use protective clothing during chemical cures why use protective chemical clothing here during these chemical cures; to prevent skin exposure to miticides
# <InputExample> label: 1.0, texts: why record all pesticide applications why record all automated pesticide spraying applications; to track resistance management and prevent overuse
# <InputExample> label: 1.0, texts: why limit entry after spraying why does limit entry requirements after spraying; to comply with safety intervals and reduce exposure risk
# <InputExample> label: 1.0, texts: why are field edges monitored more closely now why now are our field edges monitored more closely; mites often invade from weeds and borders first
# <InputExample> label: 1.0, texts: why maintain buffer zones between infested and healthy plots yet why would maintain buffer red zones alternating between infested and healthy plots; to contain mite spread
# <InputExample> label: 1.0, texts: why communicate with neighboring farmers why even communicate with these neighboring farmers; coordinated action prevents reinfestation from nearby fields
# <InputExample> label: 1.0, texts: why mow or remove border weeds why they mow or never remove border fence weeds; to eliminate reservoirs of spider mites
# <InputExample> label: 1.0, texts: why avoid planting tomatoes next to mite-prone crops why avoid planting any tomatoes planted next to moth mite - disease prone crops; crops like beans cucurbits and eggplant can harbor large mite populations
# <InputExample> label: 1.0, texts: why monitor weather forecasts ... why monitor detailed weather forecasts; hot dry periods signal higher mite risk guiding preventive action
# <InputExample> label: 1.0, texts: why increase irrigation during heatwaves but why increase optimal irrigation during extreme heatwaves; to reduce plant stress and mite-friendly microclimates
# <InputExample> label: 1.0, texts: why is windbreak installation precautionary explains why such is windbreak material installation precautionary; wind spreads mites attached to silk threads
# <InputExample> label: 1.0, texts: why is early planting sometimes a precaution ask why where is early planting sometimes just a precaution; it helps avoid peak mite populations that occur later in hot summers
# <InputExample> label: 1.0, texts: why rotate greenhouse crops with non-hosts during off-seasons why should rotate our greenhouse crops with non - host hosts during extended off - seasons; it disrupts mite survival cycles
# <InputExample> label: 1.0, texts: why keep detailed field history one why bother keep detailed field history; it helps predict risk in fields with recurrent mite problems
# <InputExample> label: 1.0, texts: why integrate multiple control strategies why integrate multiple different control group strategies; reliance on one method increases the chance of failure
# <InputExample> label: 1.0, texts: why maintain balanced soil fertility as a precaution or why maintain balanced soil fertility expectations as a constant precaution; over- or under-fertilized plants are more vulnerable to pests
# <InputExample> label: 1.0, texts: why is early removal of infested plants important why is early removal of these infested plant plants really important; it prevents population buildup and spread to healthy plants
# <InputExample> label: 1.0, texts: what is the golden precaution principle for spider mites what is in the english golden precaution clause principle for combat spider mites; prevention is easier and cheaper than curing established infestations
# <InputExample> label: 1.0, texts: what is abamectin used for in spider mite medicine what more is more abamectin used normally for processing in spider mite medicine; it controls mites by disrupting nerve impulses; widely used in tomatoes
# <InputExample> label: 1.0, texts: why is bifenazate an effective spider mite medicine so why is bifenazate so an effective predatory spider mite besides medicine; it provides quick knockdown and long residual activity
# <InputExample> label: 1.0, texts: how does spiromesifen act as a medicine how often does a spiromesifen act as yet a new medicine; it disrupts lipid synthesis targeting immature mites
# <InputExample> label: 1.0, texts: why is hexythiazox considered a special miticide why... is hexythiazox considered from a great special contact miticide; it is an ovicide—effective mainly against eggs and young larvae
# <InputExample> label: 1.0, texts: what does fenpyroximate do as a medicine or what does fenpyroximate should do for as in a medicine; it inhibits energy production in mite cells killing them
# <InputExample> label: 1.0, texts: how does cyflumetofen cure mites but how ever does this cyflumetofen cure mites; it targets mitochondrial function effective even against resistant populations
# <InputExample> label: 1.0, texts: why is chlorfenapyr effective but restricted why how is calcium chlorfenapyr effective but ph restricted; it has strong curative action but strict safety and crop-use restrictions
# <InputExample> label: 1.0, texts: what is pyridaben’s mode of action what is a pyridaben ’ if s main mode of chemical action; it interferes with mite respiration quickly reducing populations
# <InputExample> label: 1.0, texts: why is etoxazole unique among miticides why is it etoxazole also unique among many miticides; it disrupts mite development sterilizing females and stopping egg hatching
# <InputExample> label: 1.0, texts: why should miticides not be overused why should such miticides need not completely be overused; t urticae rapidly develops resistance if the same chemical is repeated
# <InputExample> label: 1.0, texts: what role does neem oil play in mite control what crucial role genes does neem seed oil play in mite resistance control; it suffocates mites and interferes with their growth
# <InputExample> label: 1.0, texts: how does insecticidal soap act as a medicine how long does insecticidal gas soap using act as a medicine; it dissolves mite cuticles killing them on contact
# <InputExample> label: 1.0, texts: what makes horticultural oil effective on what makes horticultural flower oil effective; it coats and smothers mites eggs and nymphs
# <InputExample> label: 1.0, texts: can mineral oils be used as medicine and can mineral grade oils be commonly used as medicine; yes but at recommended concentrations to avoid phytotoxicity
# <InputExample> label: 1.0, texts: why must oils be applied carefully in hot weather why must oils be applied only carefully in extreme hot autumn weather; high temperatures can cause leaf burn when oils are sprayed
# <InputExample> label: 1.0, texts: are garlic-based sprays effective medicines are their garlic - based sprays most effective pharmaceutical medicines; they act as repellents and mild suppressants but are less effective alone
# <InputExample> label: 1.0, texts: how do chili and pepper extracts act as medicines how or do chili and pepper extracts only act as herbal medicines; their compounds irritate and reduce mite feeding activity
# <InputExample> label: 1.0, texts: can organic medicines eradicate mites fully can find organic natural medicines alone eradicate mites fully; no but they effectively suppress populations when applied preventively
# <InputExample> label: 1.0, texts: why are repeated applications of soaps/oils required for why are repeated factory applications of soaps / oils when required; they lack residual action and work only on direct contact
# <InputExample> label: 1.0, texts: why are organic medicines preferred in greenhouses just why too are those organic medicines preferred in greenhouses; they’re safer for workers predators and continuous cropping
# <InputExample> label: 1.0, texts: what fungus is widely used as a mite medicine however what fungus remains is widely be used as a mite medicine; beauveria bassiana infects and kills spider mites
# <InputExample> label: 1.0, texts: how does metarhizium anisopliae act as medicine how does being metarhizium in anisopliae act like as herbal medicine; it penetrates mite cuticle and grows inside killing them
# <InputExample> label: 1.0, texts: what is the role of lecanicillium lecanii besides what contributes is the ecological role of bacterium lecanicillium lecanii; it acts as an entomopathogen reducing mite populations
# <InputExample> label: 1.0, texts: why are microbial medicines slower than chemicals why people are microbial and medicines moving slower than chemicals; they require time for infection and environmental suitability humidity
# <InputExample> label: 1.0, texts: how can biological medicines be combined with predators how exactly can biological medicines be well combined with chemical predators; selective products like b bassiana can complement predatory mites
# <InputExample> label: 1.0, texts: why store fungal biopesticides carefully so why store your fungal biopesticides so carefully; they contain living spores that lose viability if mishandled
# <InputExample> label: 1.0, texts: what advantage do biological medicines offer over chemicals what advantage to do biological dose medicines could offer over chemicals; low resistance risk and environmental safety
# <InputExample> label: 1.0, texts: can entomopathogens spread within mite populations what can entomopathogens become spread within large mite parasite populations; yes infected mites can pass the pathogen to others
# <InputExample> label: 1.0, texts: why are biopesticides ideal in organic tomato farming hence why are some biopesticides now ideal in organic tomato producer farming; they comply with organic standards and provide sustainable control
# <InputExample> label: 1.0, texts: why are they best applied in humid conditions so why are they not best applied in humid weather conditions; high humidity favors fungal germination and infection
# <InputExample> label: 1.0, texts: why is spray coverage critical for medicines why then is spray coverage so critical for best medicines; mites live under leaves so thorough coverage ensures success
# <InputExample> label: 1.0, texts: why use proper nozzle types for miticide sprays or why use proper nozzle exhaust types except for miticide spray sprays; to deliver fine droplets that reach leaf undersides
# <InputExample> label: 1.0, texts: why must label instructions be followed why must such label quality instructions be followed; to ensure correct dosage phi and worker safety
# <InputExample> label: 1.0, texts: why should application be avoided during midday why then should that application be so avoided during midday; heat and sun reduce efficacy and increase risk of phytotoxicity
# <InputExample> label: 1.0, texts: why use personal protective equipment ppe explain why women use personal health protective equipment ppe; to prevent exposure to harmful miticides
# <InputExample> label: 1.0, texts: why rotate miticide classes why would rotate miticide use classes; to slow resistance development in mite populations
# <InputExample> label: 1.0, texts: why keep spray records why keep dry spray in records; to track usage avoid overuse and plan rotations
# <InputExample> label: 1.0, texts: why avoid tank-mixing incompatible medicines then why only avoid tank - mixing as incompatible medicines; it can reduce efficacy or damage tomato foliage
# <InputExample> label: 1.0, texts: why follow re-entry intervals rei so why follow re - entry entry through intervals rei; to protect workers from toxic residues
# <InputExample> label: 1.0, texts: why follow pre-harvest intervals phi why you follow pre - harvest good intervals... phi; to ensure tomatoes are safe for consumption
# <InputExample> label: 1.0, texts: why integrate chemical and biological medicines then why integrate chemical and biological weapons medicines; to provide immediate knockdown and long-term suppression
# <InputExample> label: 1.0, texts: why avoid broad-spectrum insecticides as medicine why only avoid such broad - dose spectrum insecticides as medicine; they kill predators often worsening mite outbreaks
# <InputExample> label: 1.0, texts: why is alternating contact and systemic products useful then why next is alternating contact and non systemic products useful; it attacks mites at different stages and locations
# <InputExample> label: 1.0, texts: why treat hotspots instead of whole fields sometimes why treat their hotspots instead of using whole crop fields sometimes; spot treatments reduce cost and conserve beneficials
# <InputExample> label: 1.0, texts: why are preventive sprays discouraged more why are free preventive sprays somewhat discouraged; unnecessary sprays promote resistance and harm ipm programs
# <InputExample> label: 1.0, texts: why combine oils with miticides and why combine oils based with miticides; oils improve coverage and smother mites boosting control
# <InputExample> label: 1.0, texts: why use decision thresholds before applying medicine why you use decision point thresholds before applying for medicine; to avoid unnecessary treatments when mite levels are low
# <InputExample> label: 1.0, texts: why should biological medicines be part of ipm why should biological and medicines should be part of no ipm; they complement predators and reduce reliance on chemicals
# <InputExample> label: 1.0, texts: why consider environmental conditions before application why consider environmental soil conditions before the application; weather affects efficacy of soaps oils and fungi
# <InputExample> label: 1.0, texts: what is the guiding principle in using medicines for spider mites what is the guiding principle behind in using effective medicines for reducing spider spot mites; use the right product at the right time in rotation and always with integrated methods
# <InputExample> label: 1.0, texts: how does soil fertility influence spider mite infestations how often does this soil soil fertility influence american spider mite infestations; healthy soils support vigorous plants that better withstand mite feeding stress
# <InputExample> label: 1.0, texts: why are stressed plants more susceptible to mites ... why are even stressed banana plants more susceptible to mites; drought or nutrient imbalance weakens defenses making plants easier to colonize
# <InputExample> label: 1.0, texts: how does balanced fertility reduce mite pressure in how does optimal balanced fertility control reduce mite pressure; balanced nutrition prevents excessive lush growth or weak tissues that favor mites
# <InputExample> label: 1.0, texts: why is soil organic matter important for mite management why now is our soil organic background matter important for mite management; it improves soil water retention and plant health reducing drought stress that encourages mites
# <InputExample> label: 1.0, texts: does soil fertility directly kill mites does well soil its fertility directly kill the mites; no but it indirectly lowers their impact by boosting plant resilience
# <InputExample> label: 1.0, texts: how does excess nitrogen affect spider mite populations how does excess nitrogen production affect any spider gall mite populations; it causes soft lush foliage that attracts and supports faster mite reproduction
# <InputExample> label: 1.0, texts: why is moderate nitrogen application recommended the why is moderate neutral nitrogen application recommended; it promotes balanced growth reducing susceptibility to mites
# <InputExample> label: 1.0, texts: what form of nitrogen is safer against mite outbreaks or what some form of nitrogen gas is safer against mite outbreak outbreaks; slow-release or organic nitrogen sources reduce flushes of tender growth
# <InputExample> label: 1.0, texts: can foliar nitrogen sprays increase mite risk which can contain foliar nitrogen containing sprays also increase mite risk; yes they can create localized lush tissue that mites prefer
# <InputExample> label: 1.0, texts: why is nitrogen balance critical in ipm why water is improved nitrogen water balance critical in ipm; overuse promotes pests while deficiency weakens plant defense
# <InputExample> label: 1.0, texts: how does phosphorus p support resistance against mites on how does positive phosphorus p support resistance receptors against mites; it strengthens root systems and energy supply helping plants recover from feeding stress
# <InputExample> label: 1.0, texts: what role does potassium k play in mite tolerance in what role does plasma potassium k play in mite cell tolerance; k toughens cell walls and regulates water reducing damage from mite feeding
# <InputExample> label: 1.0, texts: how does k deficiency affect mite problems how does hepatitis k deficiency not affect calcium mite problems; deficiency causes weak tissues that mites exploit
# <InputExample> label: 1.0, texts: why is a balanced n:k ratio important see why is a correctly balanced n : d k ratio important; excess n relative to k makes plants lush and susceptible to mites
# <InputExample> label: 1.0, texts: can potassium silicate be used in tomato fertility programs can potassium silicate also be further used in their tomato fertility research programs; yes it enhances structural resistance and lowers mite damage
# <InputExample> label: 1.0, texts: how does calcium influence mite resistance how well does calcium binding influence the mite resistance; it strengthens cell walls making feeding more difficult
# <InputExample> label: 1.0, texts: what role does magnesium play in mite-infested plants on what role does magnesium play in in mite - sickness infested perennial plants; it supports chlorophyll and photosynthesis maintaining recovery ability
# <InputExample> label: 1.0, texts: why is boron important in fertility against mites or why is boron more important in fertility prevention against mites; boron supports cell wall integrity and reproduction reducing stress symptoms
# <InputExample> label: 1.0, texts: how does zinc affect tomato resilience how heavily does simple zinc reduction affect tomato resilience; it promotes enzyme activity that helps manage stress from mite feeding
# <InputExample> label: 1.0, texts: can balanced micronutrients reduce mite-related yield loss can offer balanced micronutrients to reduce mite - related bacterial yield chain loss; yes by improving tissue strength and recovery processes
# <InputExample> label: 1.0, texts: how do composts influence spider mite outbreaks wondering how do composts only influence yellow spider death mite outbreaks; they improve soil health and water balance reducing plant stress that triggers outbreaks
# <InputExample> label: 1.0, texts: why do organic soils often show fewer mite issues why do the organic fossil soils often show fewer heat mite issues; better water-holding and microbial activity enhance plant defense
# <InputExample> label: 1.0, texts: how does vermicompost help against mites how does one vermicompost protein help protect against mites; it releases nutrients slowly and enhances systemic plant resistance
# <InputExample> label: 1.0, texts: why is biochar used in fertility programs why what is biochar used extensively in female fertility programs; it improves water retention and moderates stress indirectly reducing mite pressure
# <InputExample> label: 1.0, texts: can green manures reduce mite susceptibility cheese can and green bean manures also reduce mite susceptibility; yes by enriching soil fertility and water balance
# <InputExample> label: 1.0, texts: why is soil moisture important in mite management why it is that soil moisture important in bee mite management; dry soil stresses plants which attracts mites and accelerates their reproduction
# <InputExample> label: 1.0, texts: how does fertigation help manage mites how long does water fertigation plant help manage mites; it delivers nutrients evenly avoiding flushes of weak tissue
# <InputExample> label: 1.0, texts: why avoid over-fertilization in dry soils also why avoid over - intensive fertilization in dry clay soils; it increases osmotic stress and enhances mite vulnerability
# <InputExample> label: 1.0, texts: how do mulches interact with fertility to reduce mites how precisely do mulches interact effectively with fertility treatments to reduce sex mites; they conserve soil moisture reducing drought stress linked to mite outbreaks
# <InputExample> label: 1.0, texts: why are drip systems better than flood irrigation for mite-prone crops why are the drip systems getting better than flood irrigation for food mite - contamination prone acre crops; drip reduces plant stress and delivers balanced fertility directly to roots
# <InputExample> label: 1.0, texts: how does proper fertility enhance natural plant defenses how greatly does proper plant fertility enhance natural food plant defenses; it supports production of defensive compounds that deter mites
# <InputExample> label: 1.0, texts: why do undernourished plants suffer more mite damage also why do already undernourished plants now suffer any more mite damage; weak plants lack the energy to recover from leaf tissue loss
# <InputExample> label: 1.0, texts: can silicon supplementation reduce mite damage can mechanical silicon plate supplementation reduce the mite damage; yes silicon strengthens epidermal cells lowering feeding success
# <InputExample> label: 1.0, texts: how does fertility influence predator efficiency how broadly does fertility rates influence predator efficiency; healthy plants support habitats for beneficial mites and insects
# <InputExample> label: 1.0, texts: can stress-tolerant varieties show lower mite impact with good fertility can stress - strain tolerant varieties show lower skin mite impact correlated with the good fertility; yes nutrition enhances their tolerance further
# <InputExample> label: 1.0, texts: why must fertility management be part of ipm for mites why must fertility management models be given part of future ipm for guinea mites; it reduces plant susceptibility complementing chemical and biological controls
# <InputExample> label: 1.0, texts: can fertility practices replace medicines for mites can fertility practices help replace the medicines meant for mites; no but they reduce dependency by enhancing resilience
# <InputExample> label: 1.0, texts: why integrate fertility with resistant tomato varieties more why integrate vegetable fertility with resistant tomato plant varieties; stronger plants plus genetic resistance provide dual protection
# <InputExample> label: 1.0, texts: why should fertility be adjusted in greenhouses what why should fertility be adjusted faster in large greenhouses; closed environments amplify stress conditions that favor mites
# <InputExample> label: 1.0, texts: how does fertility management reduce pesticide need how far does fertility management project reduce this pesticide need; balanced soils reduce flare-ups lowering spray frequency
# <InputExample> label: 1.0, texts: what is the ideal soil ph for tomato against mites what is the last ideal garden soil... ph for protective tomato against mites; – ensuring nutrient availability and strong growth
# <InputExample> label: 1.0, texts: why should soil fertility tests be done regularly why should the soil tissue fertility tests be done as regularly; to prevent over- or under-application of nutrients that affect mite dynamics
# <InputExample> label: 1.0, texts: what role do slow-release fertilizers play perhaps what special role... do some slow - release fertilizers play; they prevent flushes of tender growth that favor mites
# <InputExample> label: 1.0, texts: why are organic fertilizers safer against mite outbreaks why are organic nitrogen fertilizers that safer against airborne mite outbreak outbreaks; they release nutrients gradually avoiding extreme plant responses
# <InputExample> label: 1.0, texts: why adjust fertility during peak mite season why we adjust fertility rules during peak mite breeding season; to prevent lush growth that mites exploit
# <InputExample> label: 1.0, texts: how does fertigation scheduling affect mite dynamics and how highly does fertigation scheduling affect mite population dynamics; frequent light fertigation keeps growth balanced and stress low
# <InputExample> label: 1.0, texts: why balance macronutrients carefully why ask balance modern macronutrients overly carefully; excess of one nutrient eg n disrupts growth and encourages pests
# <InputExample> label: 1.0, texts: why integrate soil fertility with water management hence why integrate biological soil fertility with internal water management; nutrient uptake depends on water balance which also influences mite outbreaks
# <InputExample> label: 1.0, texts: why include organic carbon sources in tomato soils why i include organic chemical carbon by sources in tomato soils; they improve microbial activity enhancing systemic plant resistance
# <InputExample> label: 1.0, texts: what is the guiding principle of fertility in mite-prone tomatoes but what is the guiding evolutionary principle of plant fertility in mite - prone fruit tomatoes; balanced nutrition that avoids excesses prevents stress and builds resilience
# <InputExample> label: 1.0, texts: what weather favors spider mite outbreaks in tomato what bad weather weather favors spider mite virus outbreaks in tomato; hot dry and dusty conditions with low humidity
# <InputExample> label: 1.0, texts: how does rainfall affect spider mite populations specifically how does the rainfall affect spider mite host populations; heavy rain can wash mites off leaves and suppress outbreaks
# <InputExample> label: 1.0, texts: why are mites less common in cool wet climates why why are sweat mites less more common in cool wet climates; high humidity reduces reproduction and increases fungal diseases in mites
# <InputExample> label: 1.0, texts: how does temperature affect mite reproduction just how does high temperature affect mite cell reproduction; warmer temperatures speed up their life cycle increasing population growth
# <InputExample> label: 1.0, texts: what is the optimal temperature range for spider mite outbreaks thus what follows is currently the optimal temperature range for these spider mite outbreaks; – °c with low humidity
# <InputExample> label: 1.0, texts: how fast can mites reproduce at high temperatures how relatively fast can mites reproduce populations at high surface temperatures; they can complete a generation in – days under hot conditions
# <InputExample> label: 1.0, texts: why do heatwaves worsen mite problems why else do fusion heatwaves worsen mite efficiency problems; heat stresses plants while boosting mite reproduction simultaneously
# <InputExample> label: 1.0, texts: how does cool weather influence mite dynamics how strongly does even cool weather influence mite sleep dynamics; it slows mite growth and gives plants time to recover
# <InputExample> label: 1.0, texts: can extremely high temperatures > °c reduce mite numbers can extremely high high temperatures > °c further reduce mite host numbers; yes but only if combined with high humidity or leaf scorching
# <InputExample> label: 1.0, texts: why do mites thrive in greenhouses during summer and why do mites usually thrive best in greenhouses during summer; enclosed spaces amplify heat and dryness ideal for mites
# <InputExample> label: 1.0, texts: how does low humidity benefit spider mites but how does very low room humidity benefit spider mites; it prevents fungal pathogens and increases mite egg survival
# <InputExample> label: 1.0, texts: what happens to mite eggs under high humidity what happens to mite which eggs fly under sufficiently high humidity; they may fail to hatch or suffer higher mortality
# <InputExample> label: 1.0, texts: how does irrigation humidity management suppress mites how does industrial irrigation affect humidity and management suppress mites; mist or overhead irrigation raises leaf humidity unfavorable for mites
# <InputExample> label: 1.0, texts: why are mites more severe in arid regions or why are mites being more severe in the arid regions; constant low humidity supports rapid population growth
# <InputExample> label: 1.0, texts: how do dew and fog conditions affect mites how for do dew and light fog conditions greatly affect mites; prolonged leaf wetness hinders mite activity and promotes natural enemies
# <InputExample> label: 1.0, texts: why do mite outbreaks often follow dry spells after rain reason why do mite outbreaks often only follow dry feed spells after falling rain; rain knocks mites down but new tender growth after rain invites recolonization
# <InputExample> label: 1.0, texts: how does monsoon weather affect mites in tomatoes how does this monsoon year weather still affect mites in tomatoes; rain suppresses mites but outbreaks occur when dry spells return
# <InputExample> label: 1.0, texts: can dust storms influence mite outbreaks for can dust storms well influence mite virus outbreaks; yes dust-coated leaves reduce predator efficiency and favor mites
# <InputExample> label: 1.0, texts: how do frequent light rains affect mites wondering how do frequent light seasonal rains affect bee mites; they keep humidity high reducing mite reproduction
# <InputExample> label: 1.0, texts: why are mites less problematic in coastal rainy zones why bears are mites less problematic in tropical coastal than rainy zones; high humidity and frequent rains naturally regulate their populations
# <InputExample> label: 1.0, texts: how does wind influence mite dispersal how power does wind influence this mite muscle dispersal; strong winds help mites move between plants and fields
# <InputExample> label: 1.0, texts: why do dusty conditions favor mites so why do that dusty conditions really favor mites; dust weakens leaves reduces predator activity and shelters mites
# <InputExample> label: 1.0, texts: how does soil fertility interact with dust in mite outbreaks how does plant soil derived fertility control interact with dust dust in mite outbreaks; fertile but dusty soils may still favor outbreaks if stress persists
# <InputExample> label: 1.0, texts: why are mites common along roadsides yet why are mites in common around along roadsides; dust accumulation from traffic creates favorable leaf conditions
# <InputExample> label: 1.0, texts: can shelterbelts or windbreaks reduce mite risk can shelterbelts install or large windbreaks thus reduce mite pest risk; yes by lowering dust and wind dispersal
# <InputExample> label: 1.0, texts: during which season are mites most severe in tomatoes during which season they are mites most rarely severe or in tomatoes; hot dry summer or pre-monsoon seasons
# ...
# <InputExample> label: 1.0, texts: what is powdery mildew in grapes and how can it be cured if what remains is what powdery white mildew in blue grapes and how can it be cured; powdery mildew is a disease of grapes caused by erysiphe necator fungus it affects the leaves and shows symptoms such as white powdery growth on leaves and berries the cure includes sulphur/systemic fungicides canopy management
# <InputExample> label: 1.0, texts: what is apple scab in apple and how can it be cured or what are is apple scab in an apple and how can did it be cured; apple scab is a disease of apple caused by venturia inaequalis fungus it affects the leaves/fruit and shows symptoms such as olive-brown velvety lesions on leaves/fruit the cure includes resistant cultivars fungicide schedule
# <InputExample> label: 1.0, texts: what is fire blight in apple and how can it be cured what is is that fire from blight in apple trees and how can it be cured; fire blight is a disease of apple caused by erwinia amylovora bacterium it affects the leaves and shows symptoms such as shepherdâ€™s crook shoots blackened blossoms the cure includes sanitation pruning copper/antibiotics where permitted
# <InputExample> label: 1.0, texts: what is powdery mildew in papaya and how can it be cured know what business is powdery mildew in papaya and how then can making it be fully cured; powdery mildew is a disease of papaya caused by podosphaera xanthii / oidium caricae fungus it affects the leaves/fruit and shows symptoms such as white patches on leaves premature defoliation the cure includes sulphur sprays resistant varieties
# <InputExample> label: 1.0, texts: what is papaya ring spot in papaya and how can it be cured what is papaya ring that spot in papaya ring and how right can it not be so cured; papaya ring spot is a disease of papaya caused by papaya ringspot virus virus it affects the whole plant and shows symptoms such as ring spots on fruit mosaic leaves stunting the cure includes rogueing vector control barrier crops
# <InputExample> label: 1.0, texts: what is anthracnose in guava and how can it be cured what there is is anthracnose mean in guava and how can it it be properly cured; anthracnose is a disease of guava caused by colletotrichum gloeosporioides fungus it affects the fruit and shows symptoms such as sunken dark lesions on fruit the cure includes sanitation fungicide sprays
# <InputExample> label: 1.0, texts: what is bacterial blight in pomegranate and how can it be cured what aids is bacterial blight interference in our pomegranate production and how successful can it be cured; bacterial blight is a disease of pomegranate caused by xanthomonas axonopodis pv punicae bacterium it affects the fruit and shows symptoms such as oily spots on leaves/fruit cracking the cure includes copper sprays sanitation avoid overhead irrigation
# <InputExample> label: 1.0, texts: what is gray mold in strawberry and how can it be cured now what remains is gray with mold in strawberry and how can could it be cured; gray mold is a disease of strawberry caused by botrytis cinerea fungus it affects the fruit and shows symptoms such as gray fuzzy mold on berries the cure includes good airflow fungicides harvest hygiene
# <InputExample> label: 1.0, texts: what is early blight in tomato and how can it be cured what is not early when blight in tomato spreads and how can it be later cured; early blight is a disease of tomato caused by alternaria solani fungus it affects the leaves  fruit and shows symptoms such as target-like spots fruit shoulder rot the cure includes fungicide crop rotation mulch
# <InputExample> label: 1.0, texts: what is late blight in tomato and how can it be cured what is late blight left in your tomato and how much can it be more cured; late blight is a disease of tomato caused by phytophthora infestans oomycete it affects the leaves  fruit and shows symptoms such as water-soaked lesions white downy growth the cure includes preventive fungicides resistant lines
# <InputExample> label: 1.0, texts: what is bacterial wilt in tomato and how can it be cured what type is bacterial wilt used in tomato and corn how can on it be cured; bacterial wilt is a disease of tomato caused by ralstonia solanacearum bacterium it affects the vascular and shows symptoms such as sudden wilting without yellowing; brown vascular ooze the cure includes resistant rootstocks sanitation soil solarization
# <InputExample> label: 1.0, texts: what is tomato leaf curl in tomato and how can it be cured what size is a tomato bunch leaf curl in tomato and how can it be simply cured; tomato leaf curl is a disease of tomato caused by tomato leaf curl virus begomovirus virus it affects the leaves and shows symptoms such as leaf curling yellowing stunting the cure includes whitefly control resistant varieties
# <InputExample> label: 1.0, texts: what is little leaf in eggplant brinjal and how can it be cured only what is is so little of leaf in eggplant brinjal and how can it therefore be completely cured; little leaf is a disease of eggplant brinjal caused by phytoplasma phytoplasma it affects the leaves and shows symptoms such as small chlorotic leaves witchesâ€™ broom the cure includes vector control remove infected plants
# <InputExample> label: 1.0, texts: what is phomopsis blight  fruit rot in eggplant brinjal and how can it be cured from what nature is phomopsis this blight fruit rot or in eggplant brinjal and just how fertile can it never be cured; phomopsis blight  fruit rot is a disease of eggplant brinjal caused by phomopsis vexans fungus it affects the leaves/fruit and shows symptoms such as leaf blight fruit rot with concentric rings the cure includes seed treatment fungicides
# <InputExample> label: 1.0, texts: what is anthracnose  fruit rot in chilli/peppers and how can it be cured what is some anthracnose fruit they rot in chilli / bell peppers and then how long can it be heat cured; anthracnose  fruit rot is a disease of chilli/peppers caused by colletotrichum capsici fungus it affects the leaves and shows symptoms such as dark sunken lesions on fruits the cure includes seed treatment fungicides sanitation
# <InputExample> label: 1.0, texts: what is viral mosaic complex in chilli/peppers and how can it be cured what is viral and mosaic complex present in chilli / finger peppers and about how effective can it be cured; viral mosaic complex is a disease of chilli/peppers caused by cmv/pmmov/tmv etc virus it affects the whole plant and shows symptoms such as mosaic mottling leaf distortion stunting the cure includes vector control resistant hybrids rouging
# <InputExample> label: 1.0, texts: what is black rot in cabbage and how can it be cured and what causes is now black rot in cabbage and how can it still be cured; black rot is a disease of cabbage caused by xanthomonas campestris pv campestris bacterium it affects the leaves and shows symptoms such as v-shaped chlorosis from leaf margins black veins the cure includes hot-water seed treatment crop rotation
# <InputExample> label: 1.0, texts: what is downy mildew in cabbage and how can it be cured what exactly is this downy mildew in cabbage place and how can it not be thereby cured; downy mildew is a disease of cabbage caused by hyaloperonospora brassicae oomycete it affects the leaves and shows symptoms such as yellow patches downy growth underside the cure includes resistant varieties fungicide
# <InputExample> label: 1.0, texts: what is alternaria leaf spot in cauliflower and how can it be cured for what is alternaria like leaf spot in cauliflower and and how possible can it actually be successfully cured; alternaria leaf spot is a disease of cauliflower caused by alternaria brassicae fungus it affects the leaves/curd and shows symptoms such as concentric lesions curd spotting the cure includes fungicide residue management
# <InputExample> label: 1.0, texts: what is purple blotch in onion and how can it be cured what is some purple blotch in onion and cheese how can suppose it even be something cured; purple blotch is a disease of onion caused by alternaria porri fungus it affects the leaves and shows symptoms such as purple concentric lesions on leaves the cure includes fungicide sprays avoid water stress
# <InputExample> label: 1.0, texts: what is downy mildew in onion and how can it be cured what causes is a downy mildew in onion and how can is it also be so cured; downy mildew is a disease of onion caused by peronospora destructor oomycete it affects the leaves and shows symptoms such as pale patches with downy growth the cure includes good spacing fungicides
# <InputExample> label: 1.0, texts: what is rust in garlic and how can it be cured what kind is rust in any garlic wine and how pure can it be cured; rust is a disease of garlic caused by puccinia allii fungus it affects the leaves and shows symptoms such as orange pustules on leaves the cure includes fungicides rotation
# <InputExample> label: 1.0, texts: what is yellow vein mosaic in okra and how can it be cured what is yellow vein and mosaic in okra rock and... how rare can it not be cured; yellow vein mosaic is a disease of okra caused by okra yellow vein mosaic virus virus it affects the leaves  pods and shows symptoms such as bright yellow veins stunting the cure includes whitefly control resistant varieties
# <InputExample> label: 1.0, texts: what is downy mildew in cucumber and how can it be cured yet what is some downy mildew for in cucumber fish and how can it but be cured; downy mildew is a disease of cucumber caused by pseudoperonospora cubensis oomycete it affects the leaves  fruit and shows symptoms such as angular leaf spots downy growth the cure includes resistant varieties fungicides
# <InputExample> label: 1.0, texts: what is powdery mildew in cucumber and how can it be cured what becomes is powdery mildew in cucumber vinegar and... how white can it be perfectly cured; powdery mildew is a disease of cucumber caused by podosphaera xanthii fungus it affects the leaves and shows symptoms such as white powder on leaves the cure includes sulphur fungicides resistance
# <InputExample> label: 1.0, texts: what is anthracnose in pumpkin/curcurbita and how can it be cured or what is anthracnose in that pumpkin / strawberry curcurbita... and just how hot can making it be cured; anthracnose is a disease of pumpkin/curcurbita caused by colletotrichum orbiculare fungus it affects the fruit and shows symptoms such as sunken dark spots on fruit and leaves the cure includes seed treatment fungicides
# <InputExample> label: 1.0, texts: what is downy mildew in spinach and how can it be cured the what is left downy in mildew in spinach and onion how can it now be cured; downy mildew is a disease of spinach caused by peronospora effusa oomycete it affects the leaves and shows symptoms such as yellowing downy growth underside the cure includes resistant varieties sanitation
# <InputExample> label: 1.0, texts: what is leaf blight bud rot in coconut and how can it be cured what gives is leaf blight for bud rot rooted in coconut and how he can make it be cured; leaf blight bud rot is a disease of coconut caused by phytophthora palmivora oomycete it affects the leaves and shows symptoms such as rot of spear leaf foul smell the cure includes improve drainage copper fungicides
# <InputExample> label: 1.0, texts: what is lethal yellowing in coconut and how can it be cured what is that lethal yellowing in a coconut and how effective can it then be cured; lethal yellowing is a disease of coconut caused by phytoplasma phytoplasma it affects the whole plant and shows symptoms such as premature nut drop inflorescence necrosis the cure includes vector control resistant varieties where available
# <InputExample> label: 1.0, texts: what is koleroga fruit rot in arecanut and how can it be cured about what is considered koleroga fruit or rot in ancient arecanut culture and how can it be so cured; koleroga fruit rot is a disease of arecanut caused by phytophthora arecae oomycete it affects the collar/roots and shows symptoms such as rotting of buttons and immature nuts the cure includes prophylactic bordeaux mixture drainage
# <InputExample> label: 1.0, texts: what is basal stem rot in oil palm and how can it be cured what is basal plant stem rot present in oil palm and how it can before it be fully cured; basal stem rot is a disease of oil palm caused by ganoderma boninense fungus it affects the leaves and shows symptoms such as basal stem decay frond collapse the cure includes sanitation avoid replanting in infected pits
# <InputExample> label: 1.0, texts: what is leaf blotch in turmeric and how can it be cured what affect is leaf leaf blotch in liquid turmeric and to how can make it be cured; leaf blotch is a disease of turmeric caused by taphrina maculans fungus it affects the leaves and shows symptoms such as yellow rectangular lesions on leaves the cure includes fungicide sprays clean seed rhizomes
# <InputExample> label: 1.0, texts: what is leaf spot in turmeric and how can it be cured and what is a leaf spot in turmeric and then how can do it really be cured; leaf spot is a disease of turmeric caused by colletotrichum capsici fungus it affects the leaves and shows symptoms such as brown oblong spots with grey centers the cure includes seed treatment fungicides
# <InputExample> label: 1.0, texts: what is soft rot in ginger and how can it be cured what causes is soft rot deep in ginger and and how bad can it be cured; soft rot is a disease of ginger caused by pythium aphanidermatum oomycete it affects the rhizome and shows symptoms such as water-soaked rhizomes foul smell the cure includes seed rhizome treatment raised beds drainage
# <InputExample> label: 1.0, texts: what is quick wilt/foot rot in black pepper and how can it be cured what is quick enough wilt / foot like rot in a black pepper oil and how bitter can only it be cured; quick wilt/foot rot is a disease of black pepper caused by phytophthora capsici oomycete it affects the vines and shows symptoms such as sudden wilting vine death the cure includes drainage copper fungicides sanitation
# <InputExample> label: 1.0, texts: what is azhukal/ capsule rot in cardamom and how can it be cured what kind is our azhukal / capsule that rot sealed in with cardamom and how delicious can it be cured; azhukal/ capsule rot is a disease of cardamom caused by phytophthora meadii oomycete it affects the capsules/leaves and shows symptoms such as rot of capsules leaf blight the cure includes prophylactic sprays drainage
# <InputExample> label: 1.0, texts: what is cercospora leaf spot in gourd bitter/other and how can it be cured what is it cercospora like leaf spot place in a gourd bitter / tasted other and also how can it be eaten cured; cercospora leaf spot is a disease of gourd bitter/other caused by cercospora spp fungus it affects the leaves and shows symptoms such as small angular spots enlarging with grey centers the cure includes seed treatment fungicides
# <InputExample> label: 1.0, texts: what is fire blight in pear and how can it be cured what is fire of blight in honey pear and how can it really be ever cured; fire blight is a disease of pear caused by erwinia amylovora bacterium it affects the leaves/blossom and shows symptoms such as shepherdâ€™s crook blackened tissues the cure includes sanitation pruning copper
# <InputExample> label: 1.0, texts: what is anthracnose in pomegranate and how can it be cured and what is anthracnose doing in fresh pomegranate and about how infectious can it be actually cured; anthracnose is a disease of pomegranate caused by colletotrichum gloeosporioides fungus it affects the leaves/fruit and shows symptoms such as leaf spots and fruit lesions the cure includes sanitation fungicides

# %% [markdown]
# .

# %% [markdown]
# ### DataLoader
#
# ##### A `DataLoader` in machine learning efficiently manages and batches data for training and evaluation, ensuring optimized and streamlined data processing.

# %% [markdown]
# ##### Creating a Shuffled DataLoader "train_dataloader"

# %%
from torch.utils.data import DataLoader
train_dataloader = DataLoader(input_examples, shuffle=True, batch_size=16)

# %% [markdown]
# .

# %% [markdown]
# ### Sentence Transformer
#
# The SentenceTransformer('stsb-roberta-base') model is used to convert sentences into 768-dimensional vectors. These vectors capture the semantic meaning of the sentences, making it useful for tasks like sentence similarity, clustering, and semantic search. Essentially, it helps in understanding and comparing the meaning of sentences in a numerical format.

# %% [markdown]
# ##### Initialize Sentence Transformer Model

# %%
sentenceModel = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# The following layers were not sharded: encoder.layer.*.attention.self.query.bias, embeddings.LayerNorm.bias, encoder.layer.*.intermediate.dense.weight, pooler.dense.bias, encoder.layer.*.intermediate.dense.bias, encoder.layer.*.output.LayerNorm.weight, encoder.layer.*.attention.output.LayerNorm.weight, encoder.layer.*.attention.output.dense.weight, embeddings.token_type_embeddings.weight, encoder.layer.*.output.dense.weight, encoder.layer.*.attention.output.dense.bias, encoder.layer.*.output.dense.bias, encoder.layer.*.attention.self.value.weight, pooler.dense.weight, embeddings.position_embeddings.weight, encoder.layer.*.attention.self.key.weight, embeddings.word_embeddings.weight, encoder.layer.*.output.LayerNorm.bias, encoder.layer.*.attention.self.query.weight, encoder.layer.*.attention.self.key.bias, embeddings.LayerNorm.weight, encoder.layer.*.attention.output.LayerNorm.bias, encoder.layer.*.attention.self.value.bias
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
train_loss = losses.MultipleNegativesRankingLoss(sentenceModel)

# %%
print(train_loss)
# Out:
# MultipleNegativesRankingLoss(
#   (model): SentenceTransformer(
#     (0): Transformer({'max_seq_length': 128, 'do_lower_case': False, 'architecture': 'BertModel'})
#     (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   )
#   (cross_entropy_loss): CrossEntropyLoss()
# )

# %% [markdown]
# ##### Training Sentence Model with Multiple Epochs and Warmup Steps

# %%
num_epochs = 5
warmup_steps = int(len(train_dataloader) * num_epochs * 0.1)

sentenceModel.fit(
    train_objectives=[(train_dataloader, train_loss)],
    epochs=num_epochs,
    warmup_steps=warmup_steps
)
# Out:
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: chhetririya1234 (chhetririya1234-upes) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251202_173107-yxd5pm20</code>
# Syncing run <strong><a href='https://wandb.ai/chhetririya1234-upes/sentence-transformers/runs/yxd5pm20' target="_blank">crimson-smoke-2</a></strong> to <a href='https://wandb.ai/chhetririya1234-upes/sentence-transformers' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/chhetririya1234-upes/sentence-transformers' target="_blank">https://wandb.ai/chhetririya1234-upes/sentence-transformers</a>
#  View run at <a href='https://wandb.ai/chhetririya1234-upes/sentence-transformers/runs/yxd5pm20' target="_blank">https://wandb.ai/chhetririya1234-upes/sentence-transformers/runs/yxd5pm20</a>
#     <div>
#
#       <progress value='1935' max='1935' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1935/1935 06:13, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.624100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.233900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.195300</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Save to Google Drive
output_dir = '/content/drive/MyDrive/ChatbotProject/trainedModel'
sentenceModel.save(output_dir)
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# 1. Define the question you want to ask
user_query = "What is the cure for leaf spot?"  # <--- Change this to test different questions

# 2. Convert the user's question into numbers (embedding)
query_embedding = sentenceModel.encode([user_query])

# 3. Convert your database (fullQuery column) into numbers
# (We do this so we can compare the question to every possible answer)
print("Encoding database... this might take a second.")
faq_embeddings = sentenceModel.encode(newChatDF["fullQuery"].tolist())

# 4. Find the most similar question in your database
similarities = cosine_similarity(query_embedding, faq_embeddings)
best_index = np.argmax(similarities)
confidence_score = similarities[0][best_index].item()

# 5. Print the result
print("------------------------------------------------")
print(f"Question: {user_query}")
print(f"Confidence: {confidence_score:.4f}")
print("------------------------------------------------")

if confidence_score >= 0.50:
    answer = newChatDF.iloc[best_index]['response']
    print(f"Chatbot Answer: {answer}")
else:
    print("Chatbot Answer: I am not sure. Please contact an expert.")
# Out:
# Encoding database... this might take a second.
# ------------------------------------------------
# Question: What is the cure for leaf spot?
# Confidence: 0.5417
# ------------------------------------------------
# Chatbot Answer: leaf spot is a disease of turmeric caused by colletotrichum capsici fungus it affects the leaves and shows symptoms such as brown oblong spots with grey centers the cure includes seed treatment fungicides

# %% [markdown]
# ##### Preparing , Cleaning and Encoding New Query

# %%
new_query = "How do I cure spider mites?"
new_query = clean_text(new_query)
new_query_embedding = sentenceModel.encode([new_query])

# %%
print(newChatDF.columns)
# Out:
# Index(['query', 'response', 'fullQuery', 'domain', 'intent'], dtype='object')

# %%
# 1. Quick Fix: Ensure 'fullQuery' column exists
if 'fullQuery' not in newChatDF.columns:
    newChatDF['fullQuery'] = newChatDF['query']

# 2. Encode the database (The "Knowledge Base")
faq_embeddings = sentenceModel.encode(newChatDF["fullQuery"].tolist())

# 3. Compare and Find Answer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

similarities = cosine_similarity(new_query_embedding, faq_embeddings)
most_similar_index = np.argmax(similarities)
best_score = similarities[0][most_similar_index].item()

# 4. Print the Result
print("------------------------------------------------")
print(f"Query: {new_query}")
print(f"Confidence: {best_score:.4f}")
print("------------------------------------------------")

if best_score >= 0.50:
    print(f"Chatbot Answer: {newChatDF.iloc[most_similar_index]['response']}")
else:
    print("Chatbot Answer: I'm not sure about that.")
# Out:
# ------------------------------------------------
# Query: how do i cure spider mites
# Confidence: 0.7580
# ------------------------------------------------
# Chatbot Answer: prevent explosive populations with early integrated actions rather than relying solely on late-stage chemicals

# %%
# Use 'fullQuery' instead of 'query' to include the augmented data
faq_embeddings = sentenceModel.encode(newChatDF["fullQuery"].tolist())

# %% [markdown]
# ##### Importing cosine similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ##### Calculating Query Embedding Similarities

# %%
similarities = cosine_similarity(new_query_embedding, faq_embeddings)

# %%
print(similarities)
# Out:
# [[ 0.61702025  0.743132    0.401717   ... -0.02439682  0.21830782
#    0.21915418]]

# %% [markdown]
# ##### Finding the index of the most similar query and Best Score

# %%
most_similar_query_index = np.argmax(similarities)
best_score = similarities[0][most_similar_query_index].item()

# %%
print(most_similar_query_index)
# Out:
# 49

# %%
# 1. Retrieve the answer and the matched question from the dataframe
# Use the index you just found (most_similar_query_index)
best_response = newChatDF.iloc[most_similar_query_index]['response']
matched_question = newChatDF.iloc[most_similar_query_index]['query']

# 2. Print the detailed results
print("------------------------------------------------")
print(f"Matched Question: {matched_question}")
print(f"Confidence Score: {best_score:.4f}")
print("------------------------------------------------")

# 3. Logic to decide if we show the answer or not
if best_score >= 0.50:  # Threshold
    print(f"Chatbot Answer: {best_response}")
else:
    print("Chatbot Answer: I am not sure about that. Please contact an expert.")
# Out:
# ------------------------------------------------
# Matched Question: what is the ultimate cure principle for spider mites what is now the one ultimate cancer cure principle for spider mites
# Confidence Score: 0.7580
# ------------------------------------------------
# Chatbot Answer: prevent explosive populations with early integrated actions rather than relying solely on late-stage chemicals

# %% [markdown]
# ### TextBlob
#
# Importing TextBlob

# %%
from textblob import TextBlob

# %% [markdown]
# ##### Classifying The Sentiment Of The Given Input

# %%
def classify_sentiment(text):
    blob = TextBlob(text)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        print(blob)
        return "Positive"
    elif sentiment < 0:
        return "Negative"
    else:
        return "Neutral"

# %% [markdown]
# The text blob here will be helping us to counter the negative questions that user might ask which is not present in the dataset.

# %% [markdown]
# ##### Classifying Sentiment of New Query

# %%
sentiment = classify_sentiment(new_query)

# %%
sentiment
# Out:
# 'Neutral'

# %% [markdown]
# ##### Handle Negative Sentiment and Similar Query Response

# %%
if sentiment == "Negative":
    print("Please drop us a mail regarding your concerns.")
elif best_score >= 0.70:
    # Retrieve the most similar query and its response
    most_similar_query = newChatDF['query'][most_similar_query_index]
    response = responseDF[most_similar_query_index]
    print(f"Most Similar Query: {most_similar_query}")
    print(f"Response: {response}")
elif best_score >= 0.30:
    print("Sorry we are facing some technical difficulties , please write to us on contact@healthcarerocks.com")
elif best_score >= 0.20:
    print("Please write to us on our mail ID contact@healthcarerocks.com")
else:
    print("please write a mail regarding any queries related to our services")
# Out:
# Most Similar Query: what is the ultimate cure principle for spider mites what is now the one ultimate cancer cure principle for spider mites
# Response: prevent explosive populations with early integrated actions rather than relying solely on late-stage chemicals

# %%
# 1. Analyze Sentiment
sentiment = classify_sentiment(new_query)

# 2. Smart Logic (Answer FIRST, Sentiment SECOND)
if best_score >= 0.50:  # If we have a good match...
    # ...Give the answer immediately!
    print(f"Chatbot Answer: {response}")

elif sentiment == "Negative":
    # Only apologize if we DON'T know the answer AND the user is upset
    print("Chatbot Answer: I hear your frustration. I am not sure about the answer, but please email us for help.")

else:
    # Default fallback
    print("Chatbot Answer: I'm not sure about that. Please consult an expert.")
# Out:
# Chatbot Answer: prevent explosive populations with early integrated actions rather than relying solely on late-stage chemicals

# %% [markdown]
# This helps us to handle the questions that model have not yet seen or not present in the dataset,

# %% [markdown]
# .

# %% [markdown]
# ##### Best Score

# %%
best_score
# Out:
# 0.7580198645591736

# %% [markdown]
# ##### Saving the trained model into a respective directory

# %%
import os

# Use the variable name of the model you trained in Cell 37
# Do NOT initialize a new SentenceTransformer here.
model_to_save = sentenceModel

# Set the save path
save_path = "/content/saved_models/my_finetuned_sentence_model"

# Create directory
os.makedirs(save_path, exist_ok=True)

# Save the TRAINED model
model_to_save.save(save_path)

print(f"✅ Trained model saved at: {save_path}")
# Out:
# ✅ Trained model saved at: /content/saved_models/my_finetuned_sentence_model

# %%
import shutil
from google.colab import files

# 1. Zip the folder (because you can't download a folder directly)
shutil.make_archive("my_chatbot_model", 'zip', "/content/saved_models/my_finetuned_sentence_model")

# 2. Trigger the download in your browser
files.download("my_chatbot_model.zip")

# %% [markdown]
# ##### Saving Data To Pickle File

# %%
import pickle
import os

# Create local folder
os.makedirs('pickleFiles', exist_ok=True)

# Save the files
with open('pickleFiles/faq_embeddings.pkl', 'wb') as f:
    pickle.dump(faq_embeddings, f)

with open('pickleFiles/chatbot_data.pkl', "wb") as f:
    pickle.dump(newChatDF, f)

print("Files created! Now run the download script again.")
# Out:
# Files created! Now run the download script again.

# %%
import shutil
from google.colab import files
import os

# 1. Check if the folder exists (just to be sure)
if os.path.exists('pickleFiles'):
    print("✅ Found 'pickleFiles' folder!")

    # 2. Zip the folder
    print("📦 Zipping files...")
    shutil.make_archive("my_chatbot_data", 'zip', "pickleFiles")

    # 3. Download
    print("⬇️ Downloading now...")
    files.download("my_chatbot_data.zip")
else:
    print("❌ Error: The folder 'pickleFiles' still doesn't exist.")
# Out:
# ✅ Found 'pickleFiles' folder!
# 📦 Zipping files...
# ⬇️ Downloading now...

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# ### Model Loading and Testing the model

# %%
import os

# Check the folder content
folder_path = "/content/saved_models/my_finetuned_sentence_model"

if os.path.exists(folder_path):
    print(f"✅ Folder found: {folder_path}")
    print("Files inside:", os.listdir(folder_path))
else:
    print("❌ Folder not found. Did you run the save code?")
# Out:
# ✅ Folder found: /content/saved_models/my_finetuned_sentence_model
# Files inside: ['tokenizer_config.json', 'sentence_bert_config.json', 'unigram.json', 'config_sentence_transformers.json', 'config.json', 'model.safetensors', 'tokenizer.json', 'modules.json', 'special_tokens_map.json', '1_Pooling', 'README.md']

# %%
best_score
# Out:
# 0.7524635195732117

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# ### Fine Tuned Chatbot Using BART Transformer

# %%
import pandas as pd
import os

# Assume newChatDF from the previous section is available in the kernel state.
# This DataFrame already contains 'response' and 'fullQuery' (which combines original and augmented queries).

# Create a DataFrame suitable for the BART fine-tuning, renaming 'fullQuery' to 'query'
# to match the expected column names in subsequent cells.
bart_df = newChatDF[['query', 'response']].copy()
bart_df.rename(columns={'query': 'query'}, inplace=True)

# Define the path for the new CSV file
file_path = "/content/merged_cleaned-data.csv"

# Save the DataFrame to a CSV file
bart_df.to_csv(file_path, index=False)

# Load the newly created CSV file
df = pd.read_csv(file_path)

# Now df is defined
print(df.head())
# Out:
#                                                query  \
# 0  what is the first step in curing a spider mite...
# 1  how does high-pressure water spray help cure s...
# 2  why is pruning useful in mite cure why what is...
# 3  can dust reduction be considered a cure for sp...
# 4  how does improving air circulation cure mite o...
#
#                                             response
# 0  immediately remove and destroy heavily infeste...
# 1  it physically dislodges mites from leaves; rep...
# 2  it eliminates infestation hotspots and improve...
# 3  yes reducing dust lowers stress on plants and ...
# 4  better airflow reduces hot dry microclimates w...

# %% [markdown]
# ##### Creating a DataFrame

# %%
# Example: Use query and response columns from your existing DataFrame
newQueryDataset = df['query'].tolist()
responseDF = df['response'].tolist()


# Now this will work
import pandas as pd
newChatDF = pd.DataFrame({
    "query": newQueryDataset,
    "response": responseDF
})

print(newChatDF)
# Out:
#                                                   query  \
# 0     what is the first step in curing a spider mite...
# 1     how does high-pressure water spray help cure s...
# 2     why is pruning useful in mite cure why what is...
# 3     can dust reduction be considered a cure for sp...
# 4     how does improving air circulation cure mite o...
# ...                                                 ...
# 6184  what is quick wilt/foot rot in black pepper an...
# 6185  what is azhukal/ capsule rot in cardamom and h...
# 6186  what is cercospora leaf spot in gourd bitter/o...
# 6187  what is fire blight in pear and how can it be ...
# 6188  what is anthracnose in pomegranate and how can...
#
#                                                response
# 0     immediately remove and destroy heavily infeste...
# 1     it physically dislodges mites from leaves; rep...
# 2     it eliminates infestation hotspots and improve...
# 3     yes reducing dust lowers stress on plants and ...
# 4     better airflow reduces hot dry microclimates w...
# ...                                                 ...
# 6184  quick wilt/foot rot is a disease of black pepp...
# 6185  azhukal/ capsule rot is a disease of cardamom ...
# 6186  cercospora leaf spot is a disease of gourd bit...
# 6187  fire blight is a disease of pear caused by erw...
# 6188  anthracnose is a disease of pomegranate caused...
#
# [6189 rows x 2 columns]

# %%
newChatDF.head()
# Out:
#                                                query  \
# 0  what is the first step in curing a spider mite...
# 1  how does high-pressure water spray help cure s...
# 2  why is pruning useful in mite cure why what is...
# 3  can dust reduction be considered a cure for sp...
# 4  how does improving air circulation cure mite o...
#
#                                             response
# 0  immediately remove and destroy heavily infeste...
# 1  it physically dislodges mites from leaves; rep...
# 2  it eliminates infestation hotspots and improve...
# 3  yes reducing dust lowers stress on plants and ...
# 4  better airflow reduces hot dry microclimates w...

# %% [markdown]
# The dataframe has two columns query and response.

# %% [markdown]
# .

# %% [markdown]
# ##### Checking the shape of the dataset

# %%
newChatDF.shape
# Out:
# (6189, 2)

# %% [markdown]
# The Dataset has 1681 rows and 2 columns.

# %% [markdown]
# .

# %% [markdown]
# ##### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##### Spliting the data into training and validation sets.

# %%
train_df, val_df = train_test_split(newChatDF, test_size=0.2, random_state=42)

# %% [markdown]
# ##### Checking the shape of the dataframe

# %%
train_df.shape, val_df.shape
# Out:
# ((4951, 2), (1238, 2))

# %% [markdown]
# After the split the training dataset train_df has 1344 rows and 2 columns where validation dataset val_df has 337 rows and 2 columns.

# %% [markdown]
# .

# %%
train_df.head()
# Out:
#                                                   query  \
# 3950  what sanitation steps reduce early blight on t...
# 1020  what is the scientific name of the early bligh...
# 1545  where does the late blight pathogen survive be...
# 1433  how does staking or trellising help tomato hea...
# 3599  can bacterial spot spread via tools or hands w...
#
#                                                response
# 3950  scout tomato biweekly; remove infected tissue ...
# 1020                                  alternaria solani
# 1545  infected potato/tomato debris cull piles and v...
# 1433  it improves airflow reduces fruit contact with...
# 3599  scout tomato every – days; remove infected tis...

# %%
val_df.head()
# Out:
#                                                   query  \
# 996   can windbreaks reduce tylcv spread can agricul...
# 468   afternoon vs overnight humidity afternoon day ...
# 3098  how can i prune strawberry to boost airflow an...
# 2127  where does septoria leaf spot survive between ...
# 2080  how can fungicides be used for septoria how ca...
#
#                                                response
# 996                  yes by limiting whitefly dispersal
# 468    overnight wetness is more critical for infection
# 3098  for strawberry keep soil evenly moist; use fur...
# 2127  on plant debris volunteer tomatoes and solanac...
# 2080     apply preventively when weather favors disease

# %% [markdown]
# ##### Reseting Index for Training and Validation Data

# %%
train_data = train_df.reset_index(drop=True)
validation_data = val_df.reset_index(drop=True)

# %%
train_data.head()
# Out:
#                                                query  \
# 0  what sanitation steps reduce early blight on t...
# 1  what is the scientific name of the early bligh...
# 2  where does the late blight pathogen survive be...
# 3  how does staking or trellising help tomato hea...
# 4  can bacterial spot spread via tools or hands w...
#
#                                             response
# 0  scout tomato biweekly; remove infected tissue ...
# 1                                  alternaria solani
# 2  infected potato/tomato debris cull piles and v...
# 3  it improves airflow reduces fruit contact with...
# 4  scout tomato every – days; remove infected tis...

# %%
train_data['query'][0]
# Out:
# 'what sanitation steps reduce early blight on tomato what if sanitation steps can reduce early blight levels on tomato'

# %%
validation_data.head()
# Out:
#                                                query  \
# 0  can windbreaks reduce tylcv spread can agricul...
# 1  afternoon vs overnight humidity afternoon day ...
# 2  how can i prune strawberry to boost airflow an...
# 3  where does septoria leaf spot survive between ...
# 4  how can fungicides be used for septoria how ca...
#
#                                             response
# 0                 yes by limiting whitefly dispersal
# 1   overnight wetness is more critical for infection
# 2  for strawberry keep soil evenly moist; use fur...
# 3  on plant debris volunteer tomatoes and solanac...
# 4     apply preventively when weather favors disease

# %% [markdown]
# ### BART Transformers
#
# ##### Importing Bart libraries

# %%
from transformers import BartTokenizer, BartForConditionalGeneration, Trainer, TrainingArguments
from datasets import Dataset, DatasetDict

# %% [markdown]
# ##### Initializing tokenizer

# %%
tokenizer = BartTokenizer.from_pretrained('facebook/bart-base')
# Out:
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]

# %% [markdown]
# ##### Preprocessing By Tokenizing And Creating Labels

# %%
def preprocess_function(examples):
    inputs = tokenizer(examples["query"], padding="max_length", truncation=True, max_length=512)
    targets = tokenizer(examples["response"], padding="max_length", truncation=True, max_length=512)
    inputs["labels"] = targets["input_ids"]
    return inputs

# %% [markdown]
# ##### Creating Dataset Objects from Pandas DataFrames

# %%
train_dataset = Dataset.from_pandas(train_data)
validation_dataset = Dataset.from_pandas(validation_data)

# %% [markdown]
# ##### Apply Preprocessing Function to Datasets

# %%
from datasets import load_dataset, DatasetDict
from sklearn.model_selection import train_test_split
import pandas as pd

# Load CSV into pandas
df = pd.read_csv("merged_cleaned-data.csv", names=["query", "response"])

# Split manually
train_df, val_df = train_test_split(df, test_size=0.2)

# Convert to Hugging Face Dataset
from datasets import Dataset
dataset = DatasetDict({
    'train': Dataset.from_pandas(train_df),
    'validation': Dataset.from_pandas(val_df)
})

# %% [markdown]
# ##### Creating dataset dictionary

# %%
dataset_dict = DatasetDict({
    'train': train_dataset,
    'validation': validation_dataset
})

# %% [markdown]
# ##### Initializing BART Model for Conditional Generation

# %%
model = BartForConditionalGeneration.from_pretrained('facebook/bart-base')
# Out:
# model.safetensors:   0%|          | 0.00/558M [00:00<?, ?B/s]
# The following layers were not sharded: model.decoder.layers.*.encoder_attn.k_proj.bias, model.decoder.layers.*.self_attn_layer_norm.bias, model.shared.weight, model.encoder.layers.*.self_attn_layer_norm.bias, model.encoder.layers.*.self_attn.q_proj.bias, model.encoder.embed_tokens.weight, model.decoder.layers.*.fc*.weight, model.decoder.layers.*.self_attn.v_proj.weight, model.encoder.layers.*.fc*.weight, model.encoder.layers.*.final_layer_norm.weight, model.encoder.layernorm_embedding.bias, model.decoder.embed_tokens.weight, model.decoder.layers.*.final_layer_norm.weight, model.encoder.layers.*.self_attn.v_proj.weight, model.decoder.layers.*.self_attn.k_proj.weight, model.encoder.layers.*.self_attn.q_proj.weight, model.decoder.layers.*.self_attn.k_proj.bias, final_logits_bias, model.decoder.layers.*.self_attn.out_proj.bias, model.decoder.layers.*.encoder_attn_layer_norm.bias, model.encoder.layers.*.self_attn.out_proj.bias, model.decoder.layers.*.encoder_attn.q_proj.bias, model.decoder.embed_positions.weight, model.encoder.layers.*.self_attn.out_proj.weight, model.decoder.layers.*.encoder_attn.out_proj.bias, model.decoder.layers.*.self_attn.v_proj.bias, model.decoder.layernorm_embedding.weight, model.decoder.layers.*.self_attn.q_proj.weight, model.decoder.layers.*.encoder_attn.v_proj.weight, model.decoder.layers.*.self_attn.out_proj.weight, model.encoder.layers.*.fc*.bias, model.decoder.layers.*.fc*.bias, model.encoder.layernorm_embedding.weight, model.encoder.layers.*.self_attn.v_proj.bias, model.encoder.layers.*.self_attn_layer_norm.weight, model.decoder.layers.*.self_attn_layer_norm.weight, model.decoder.layers.*.final_layer_norm.bias, model.encoder.embed_positions.weight, model.decoder.layers.*.self_attn.q_proj.bias, model.encoder.layers.*.self_attn.k_proj.weight, lm_head.weight, model.decoder.layernorm_embedding.bias, model.decoder.layers.*.encoder_attn.k_proj.weight, model.decoder.layers.*.encoder_attn.out_proj.weight, model.decoder.layers.*.encoder_attn.v_proj.bias, model.decoder.layers.*.encoder_attn.q_proj.weight, model.encoder.layers.*.self_attn.k_proj.bias, model.encoder.layers.*.final_layer_norm.bias, model.decoder.layers.*.encoder_attn_layer_norm.weight

# %%
# !pip install -U transformers

from transformers import TrainingArguments
print(TrainingArguments)
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.2)
# Collecting transformers
#   Downloading transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)
# Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 9.1 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.2
#     Uninstalling transformers-4.57.2:
#       Successfully uninstalled transformers-4.57.2
# Successfully installed transformers-4.57.3
# <class 'transformers.training_args.TrainingArguments'>

# %% [markdown]
# ##### Training The Model

# %%
# !pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.57.2

# %%
print(transformers.__file__)
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/__init__.py

# %%
from transformers import TrainingArguments
training_args = TrainingArguments(
    output_dir='./results',
    learning_rate=3e-5,
    per_device_train_batch_size=8,
    num_train_epochs=5,
    weight_decay=0.01,
    logging_dir='./logs',
    remove_unused_columns=True # Changed from False to True
)

# %% [markdown]
# ##### Saving the trained model into chatbot_model directory

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

# Replace with your fine-tuned model and tokenizer
model.save_pretrained("/Users/riya/Documents/my_finetuned_model")
tokenizer.save_pretrained("/Users/riya/Documents/my_finetuned_model")
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py:3918: UserWarning: Moving the following attributes in the config to the generation config: {'early_stopping': True, 'num_beams': 4, 'no_repeat_ngram_size': 3, 'forced_bos_token_id': 0}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# ('/Users/riya/Documents/my_finetuned_model/tokenizer_config.json',
#  '/Users/riya/Documents/my_finetuned_model/special_tokens_map.json',
#  '/Users/riya/Documents/my_finetuned_model/vocab.json',
#  '/Users/riya/Documents/my_finetuned_model/merges.txt',
#  '/Users/riya/Documents/my_finetuned_model/added_tokens.json')

# %%
model.save_pretrained("./my_finetuned_model")
tokenizer.save_pretrained("./my_finetuned_model")
# Out:
# ('./my_finetuned_model/tokenizer_config.json',
#  './my_finetuned_model/special_tokens_map.json',
#  './my_finetuned_model/vocab.json',
#  './my_finetuned_model/merges.txt',
#  './my_finetuned_model/added_tokens.json')

# %%
# !zip -r my_finetuned_model.zip my_finetuned_model
# Out:
#   adding: my_finetuned_model/ (stored 0%)
#   adding: my_finetuned_model/tokenizer_config.json (deflated 75%)
#   adding: my_finetuned_model/config.json (deflated 64%)
#   adding: my_finetuned_model/vocab.json (deflated 68%)
#   adding: my_finetuned_model/model.safetensors (deflated 41%)
#   adding: my_finetuned_model/merges.txt (deflated 53%)
#   adding: my_finetuned_model/special_tokens_map.json (deflated 85%)
#   adding: my_finetuned_model/generation_config.json (deflated 46%)

# %%
from google.colab import files
files.download("my_finetuned_model.zip")

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .
